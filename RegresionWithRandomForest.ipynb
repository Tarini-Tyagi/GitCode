# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loading data
df=pd.read_csv('http://13.234.66.67/summer19/datasets/pos_sal.csv')

# %% [markdown]
# Edureka
#
#
# EXPERIENCE:
#
#
# 30hrs video --- Data Science --- Salary
#
#
# 2hrs video --- Linux    ---- salary
#
#
# 30hrs ------ Python ---- Salary
#
#
#
# if 2 yr exp of linux, 3 yr exp of python then what will be the sal????  Predict

# %%
x=df.iloc[:,1:2].values # exp
y=df.iloc[:,2:].values

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regr=RandomForestRegressor()
trained=regr.fit(x,y)
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
plt.xlabel('Position')
plt.ylabel('Salary')
plt.scatter(x,y,label="Actual sal")
plt.plot(x,trained.predict(x),label="Random Forest Regressor")
plt.legend()
plt.show()
